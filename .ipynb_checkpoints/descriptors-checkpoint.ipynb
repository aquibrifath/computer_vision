# %%
import cv2

# %%
print("Hello world")
# Out:
# Hello world

# %%
img = cv2.imread('/home/aquirah/Pictures/Aquib_image.jpg')

# %%
cv2.imshow('Original', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55dfd1fb2450) is not the object's thread (0x55dfd20943c0).
# Cannot move to target thread (0x55dfd1fb2450)
#
# QObject::moveToThread: Current thread (0x55dfd1fb2450) is not the object's thread (0x55dfd20943c0).
# Cannot move to target thread (0x55dfd1fb2450)
#
# QObject::moveToThread: Current thread (0x55dfd1fb2450) is not the object's thread (0x55dfd20943c0).
# Cannot move to target thread (0x55dfd1fb2450)
#
# QObject::moveToThread: Current thread (0x55dfd1fb2450) is not the object's thread (0x55dfd20943c0).
# Cannot move to target thread (0x55dfd1fb2450)
#
# QObject::moveToThread: Current thread (0x55dfd1fb2450) is not the object's thread (0x55dfd20943c0).
# Cannot move to target thread (0x55dfd1fb2450)
#
# QObject::moveToThread: Current thread (0x55dfd1fb2450) is not the object's thread (0x55dfd20943c0).
# Cannot move to target thread (0x55dfd1fb2450)
#
# ...
